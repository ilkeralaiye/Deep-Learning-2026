# %%
import numpy as np

# %%
matrix = [[5,10],[15,20]]

# %%
type(matrix)
# Out:
# list

# %%
matrix[1][0]
# Out:
# 15

# %%
matrix[1][-1]
# Out:
# 20

# %%
nMatrix = np.array([[10, 20],[30, 40]])

# %%
nMatrix
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
nMatrix[0][0]
# Out:
# np.int64(10)

# %%
nMatrix.sum()
# Out:
# np.int64(100)

# %%
np.ones((4, 2))
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
mMatrix = np.array([[100, 2],[300, 4]])

# %%
nMatrix
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
mMatrix
# Out:
# array([[100,   2],
#        [300,   4]])

# %%
nMatrix + mMatrix
# Out:
# array([[110,  22],
#        [330,  44]])

# %%
row_matrix = np.array([[70, 75]])

# %%
row_matrix
# Out:
# array([[70, 75]])

# %%
mMatrix + row_matrix
# Out:
# array([[170,  77],
#        [370,  79]])

# %%
nMatrix
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
mMatrix
# Out:
# array([[100,   2],
#        [300,   4]])

# %%
nMatrix * mMatrix
# Out:
# array([[1000,   40],
#        [9000,  160]])

# %%
#np.mul

# %%
np.multiply(nMatrix, mMatrix)
# Out:
# array([[1000,   40],
#        [9000,  160]])

# %%
np.dot(nMatrix, mMatrix)
# Out:
# array([[ 7000,   100],
#        [15000,   220]])

# %%
nMatrix(nMatrix > 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 nMatrix(nMatrix > 10)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
xMatrix = np.random.randint(1, 1000, 50)

# %%
xMatrix
# Out:
# array([880, 610, 747, 734, 117, 480, 489, 978, 604, 969, 667, 473,  24,
#        933, 688,  39, 364,  74, 139, 132, 805, 118, 471, 589, 705, 625,
#        227, 616,  40, 604, 917, 448, 311, 621, 854, 525, 612, 254, 343,
#        566, 565, 458, 462, 365, 368, 703, 473, 963, 988, 631], dtype=int32)

# %%
xMatrix[xMatrix > 200]
# Out:
# array([880, 610, 747, 734, 480, 489, 978, 604, 969, 667, 473, 933, 688,
#        364, 805, 471, 589, 705, 625, 227, 616, 604, 917, 448, 311, 621,
#        854, 525, 612, 254, 343, 566, 565, 458, 462, 365, 368, 703, 473,
#        963, 988, 631], dtype=int32)

# %%
xMatrix.transpose()
# Out:
# array([880, 610, 747, 734, 117, 480, 489, 978, 604, 969, 667, 473,  24,
#        933, 688,  39, 364,  74, 139, 132, 805, 118, 471, 589, 705, 625,
#        227, 616,  40, 604, 917, 448, 311, 621, 854, 525, 612, 254, 343,
#        566, 565, 458, 462, 365, 368, 703, 473, 963, 988, 631], dtype=int32)

# %%
yMatrix = np.array([np.random.randint(1,100, 5), np.random.randint(1,100, 5), np.random.randint(1,100, 5), np.random.randint(1,100, 5), np.random.randint(1,100, 5)])

# %%
yMatrix
# Out:
# array([[62, 97, 39, 36, 54],
#        [14, 12, 89,  9,  8],
#        [29, 20, 51, 64, 23],
#        [76, 87, 85,  1,  1],
#        [29,  9, 30, 23, 55]], dtype=int32)

# %%
yMatrix.T
# Out:
# array([[62, 14, 29, 76, 29],
#        [97, 12, 20, 87,  9],
#        [39, 89, 51, 85, 30],
#        [36,  9, 64,  1, 23],
#        [54,  8, 23,  1, 55]], dtype=int32)

# %%
xMatrix.reshape(20, -1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 xMatrix.reshape(20, -1)
#
# ValueError: cannot reshape array of size 50 into shape (20,newaxis)

# %%
xMatrix.reshape(10, -1)
# Out:
# array([[880, 610, 747, 734, 117],
#        [480, 489, 978, 604, 969],
#        [667, 473,  24, 933, 688],
#        [ 39, 364,  74, 139, 132],
#        [805, 118, 471, 589, 705],
#        [625, 227, 616,  40, 604],
#        [917, 448, 311, 621, 854],
#        [525, 612, 254, 343, 566],
#        [565, 458, 462, 365, 368],
#        [703, 473, 963, 988, 631]], dtype=int32)

# %%
data = np.array([10, 12, 13, 14, 18, 25, 100, 105])

# %%
mean = np.mean(data)

# %%
mean
# Out:
# np.float64(37.125)

# %%
std = np.std(data)

# %%
std
# Out:
# np.float64(38.00801724636527)

# %%
z_scores = (data - mean) / std

# %%
z_scores
# Out:
# array([-0.71366522, -0.66104474, -0.6347345 , -0.60842427, -0.50318331,
#        -0.31901164,  1.65425625,  1.78580744])

# %%
z_scores[z_scores > 1]
# Out:
# array([1.65425625, 1.78580744])

# %%
data[z_scores > 1]
# Out:
# array([100, 105])

# %%
# 2x + 3y = 8, 5x + 7y = 19

# %%
coefficients = np.array([[2,3],[5,7]])

# %%
constants = np.array([8,19])

# %%
solution = np.linalg.solve(coefficients, constants)

# %%
solution
# Out:
# array([1., 2.])
