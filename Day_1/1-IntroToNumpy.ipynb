# %%
import numpy as np

# %%
my_list = [10, 20, 30, 40]

# %%
type(my_list)
# Out:
# list

# %%
np.array(my_list)
# Out:
# array([10, 20, 30, 40])

# %%
my_numpy_array = np.array(my_list)

# %%
type(my_numpy_array)
# Out:
# numpy.ndarray

# %%
my_numpy_array.max()
# Out:
# np.int64(40)

# %%
numpy.ones(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 numpy.ones(6)
#
# NameError: name 'numpy' is not defined

# %%
np.ones(6)
# Out:
# array([1., 1., 1., 1., 1., 1.])

# %%
np.random.random(5)
# Out:
# array([0.52831554, 0.67467964, 0.4334797 , 0.29364159, 0.6859611 ])

# %%
# array arithmetic

# %%
 np_array = np.arange(0, 20, 4)

# %%
np_array[4]
# Out:
# np.int64(16)

# %%
np_array[-1::-1]
# Out:
# array([16, 12,  8,  4,  0])

# %%
np.random.randn(4,3)
# Out:
# array([[-0.03238321,  1.17600071,  0.30972367],
#        [ 2.23821706,  1.02006698,  0.47812065],
#        [-0.35176062, -1.38447515, -1.08722754],
#        [ 1.33881639,  0.27951794,  2.18874424]])
