# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import torch
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
import torch.nn as nn

RANDOMNESS_VALUE = 42
LEARN_RATE = 0.01
EPOCHS = 400

# %%
# Read the 08-seismic_activity_svm.csv file
df = pd.read_csv("08-seismic_activity_svm.csv")

# %%
# We have 3 columns, underground_wave_energy, vibration_axis_variation, seismic_event_detected
df.head()
# Out:
#    underground_wave_energy  vibration_axis_variation  seismic_event_detected
# 0                 9.539392                 -3.000000                       0
# 1                 9.558241                 -2.939394                       0
# 2                 9.576669                 -2.878788                       0
# 3                 9.594678                 -2.818182                       0
# 4                 9.612272                 -2.757576                       0

# %%
plt.figure(figsize=(10, 6))

df_underground_wave_energy = df["underground_wave_energy"]
df_vibration_axis_variation = df["vibration_axis_variation"]
df_seismic_event_detected = df["seismic_event_detected"]

sns.scatterplot(x=df_underground_wave_energy, y=df_vibration_axis_variation, hue=df_seismic_event_detected)
plt.show()

# %%
X = df[["underground_wave_energy", "vibration_axis_variation"]].values
y = df["seismic_event_detected"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOMNESS_VALUE)

# %%
print(f"length of X_train: {len(X_train)}, length of y_train: {len(y_train)}")
print(f"length of X_test: {len(X_test)}, length of y_test: {len(y_test)}")
# Out:
# length of X_train: 320, length of y_train: 320
# length of X_test: 80, length of y_test: 80

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)

y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# %%
print(f"X_train.shape: {X_train.shape}")
print(f"X_test.shape: {X_test.shape}")
print(f"y_train.shape: {y_train.shape}")
print(f"y_test.shape: {y_test.shape}")
# Out:
# X_train.shape: torch.Size([320, 2])
# X_test.shape: torch.Size([80, 2])
# y_train.shape: torch.Size([320, 1])
# y_test.shape: torch.Size([80, 1])

# %%
class SeismicActivityModel(nn.Module):

    # We have 2 input, 3 hidden layers with 5 neurons each, and 1 output
    def __init__(self):
        super().__init__()
        self.first_layer = nn.Linear(in_features=2, out_features=5)
        self.second_layer = nn.Linear(in_features=5, out_features=5)
        self.third_layer = nn.Linear(in_features=5, out_features=1)

        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.first_layer(x)
        x = self.relu(x)
        x = self.second_layer(x)
        x = self.relu(x)
        x = self.third_layer(x)
        return x

# %%
model = SeismicActivityModel()
print(model)
# Out:
# SeismicActivityModel(
#   (first_layer): Linear(in_features=2, out_features=5, bias=True)
#   (second_layer): Linear(in_features=5, out_features=5, bias=True)
#   (third_layer): Linear(in_features=5, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARN_RATE)

# %%
def calculate_accuracy(test_dataframe, prediction_dataframe):

    correct = torch.eq(test_dataframe, prediction_dataframe).sum().item()
    total = len(test_dataframe)

    accuracy = correct / total

    return accuracy * 100

# %%
y_logits = model(X_train)[:20]
y_pred_probs = torch.sigmoid(y_logits)
y_preds = torch.round(y_pred_probs)

# %%
calculate_accuracy(y_test[:20], y_preds)
# Out:
# 50.0

# %%
torch.manual_seed(RANDOMNESS_VALUE)

for epoch in range(EPOCHS):

    # | ----- | Training Mode | ----- |
    model.train() # Set the model to training mode
    
    # Forward pass
    y_logits = model(X_train) 
    # Get the predicted probabilities and round them to get binary predictions
    y_pred = torch.round(torch.sigmoid(y_logits)) 
    # Calculate the Loss
    loss = loss_function(y_logits, y_train) 
    # Calculate the accuracy
    accuracy = calculate_accuracy(y_train, y_pred) 

    optimizer.zero_grad() # Zero the gradients
    loss.backward() # Backward pass
    optimizer.step() # Update the weights

    # | ----- | Evaluation Mode | ----- |
    model.eval() # Set the model to evaluation mode
    with torch.inference_mode():

        test_logits = model(X_test) # Forward pass
        test_pred = torch.round(torch.sigmoid(test_logits)) # Get the predicted probabilities and round them to get binary predictions
        test_loss = loss_function(test_logits, y_test) # Calculate the loss
        test_accuracy = calculate_accuracy(y_test, test_pred) # Calculate the accuracy

        if epoch % 10 == 0:
            print(f"Epoch: {epoch} | Loss: {loss:.4f} | Accuracy: {accuracy:.2f}% | Test Loss: {test_loss:.3f} | Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Epoch: 0 | Loss: 0.7676 | Accuracy: 48.75% | Test Loss: 0.691 | Test Accuracy: 55.00%
# Epoch: 10 | Loss: 0.6363 | Accuracy: 54.69% | Test Loss: 0.587 | Test Accuracy: 72.50%
# Epoch: 20 | Loss: 0.5659 | Accuracy: 52.81% | Test Loss: 0.541 | Test Accuracy: 57.50%
# Epoch: 30 | Loss: 0.5155 | Accuracy: 71.88% | Test Loss: 0.513 | Test Accuracy: 68.75%
# Epoch: 40 | Loss: 0.4567 | Accuracy: 79.38% | Test Loss: 0.463 | Test Accuracy: 77.50%
# Epoch: 50 | Loss: 0.3841 | Accuracy: 84.69% | Test Loss: 0.379 | Test Accuracy: 86.25%
# Epoch: 60 | Loss: 0.2937 | Accuracy: 97.50% | Test Loss: 0.266 | Test Accuracy: 98.75%
# Epoch: 70 | Loss: 0.2085 | Accuracy: 99.69% | Test Loss: 0.177 | Test Accuracy: 98.75%
# Epoch: 80 | Loss: 0.1357 | Accuracy: 100.00% | Test Loss: 0.108 | Test Accuracy: 100.00%
# Epoch: 90 | Loss: 0.0805 | Accuracy: 100.00% | Test Loss: 0.063 | Test Accuracy: 100.00%
# Epoch: 100 | Loss: 0.0419 | Accuracy: 100.00% | Test Loss: 0.033 | Test Accuracy: 100.00%
# Epoch: 110 | Loss: 0.0182 | Accuracy: 100.00% | Test Loss: 0.015 | Test Accuracy: 100.00%
# Epoch: 120 | Loss: 0.0080 | Accuracy: 100.00% | Test Loss: 0.007 | Test Accuracy: 100.00%
# Epoch: 130 | Loss: 0.0046 | Accuracy: 100.00% | Test Loss: 0.004 | Test Accuracy: 100.00%
# Epoch: 140 | Loss: 0.0033 | Accuracy: 100.00% | Test Loss: 0.003 | Test Accuracy: 100.00%
# Epoch: 150 | Loss: 0.0026 | Accuracy: 100.00% | Test Loss: 0.002 | Test Accuracy: 100.00%
# Epoch: 160 | Loss: 0.0021 | Accuracy: 100.00% | Test Loss: 0.002 | Test Accuracy: 100.00%
# Epoch: 170 | Loss: 0.0018 | Accuracy: 100.00% | Test Loss: 0.002 | Test Accuracy: 100.00%
# Epoch: 180 | Loss: 0.0016 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 190 | Loss: 0.0014 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 200 | Loss: 0.0012 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 210 | Loss: 0.0011 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 220 | Loss: 0.0010 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 230 | Loss: 0.0009 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 240 | Loss: 0.0008 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 250 | Loss: 0.0007 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 260 | Loss: 0.0006 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 270 | Loss: 0.0006 | Accuracy: 100.00% | Test Loss: 0.001 | Test Accuracy: 100.00%
# Epoch: 280 | Loss: 0.0005 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 290 | Loss: 0.0005 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 300 | Loss: 0.0004 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 310 | Loss: 0.0004 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 320 | Loss: 0.0004 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 330 | Loss: 0.0004 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 340 | Loss: 0.0003 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 350 | Loss: 0.0003 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 360 | Loss: 0.0003 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 370 | Loss: 0.0003 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 380 | Loss: 0.0003 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%
# Epoch: 390 | Loss: 0.0002 | Accuracy: 100.00% | Test Loss: 0.000 | Test Accuracy: 100.00%

# %%
for i in range(20):
    print(f"Actual: {y_test[i].item()} | Predicted: {test_pred[i].item()}")
# Out:
# Actual: 1.0 | Predicted: 1.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 0.0 | Predicted: 0.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 1.0 | Predicted: 1.0
# Actual: 1.0 | Predicted: 1.0

# %%
def plot_nonlinear_decision_boundary(model, X, y):

    # Grid alanını tanımla (tüm veri aralığını kapsasın)
    x_min, x_max = X[:,0].min() - 1, X[:,0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    
    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 300),
        np.linspace(y_min, y_max, 300)
    )

    # Grid'i modele sokmak için tensor'a çevir
    grid_points = torch.tensor(
        np.c_[xx.ravel(), yy.ravel()],
        dtype=torch.float32
    )

    # Tahmin al
    model.eval()
    with torch.inference_mode():
        logits = model(grid_points)
        preds = torch.sigmoid(logits).numpy().reshape(xx.shape)  # probability map

    # Decision boundary çizimi (0.5 threshold)
    plt.contourf(xx, yy, preds, cmap=plt.cm.RdYlBu, alpha=0.7)
    
    # Gerçek noktalar
    plt.scatter(X[:,0], X[:,1], c=y.squeeze(), cmap=plt.cm.RdYlBu, s=30, edgecolor="k")
    plt.xlabel("underground_wave_energy")
    plt.ylabel("vibration_axis_variation")
    plt.title("Non-linear Decision Boundary")

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title("Train")
plot_nonlinear_decision_boundary(model, X_train, y_train)

plt.subplot(1, 2, 2)
plt.title("Test")
plot_nonlinear_decision_boundary(model, X_test, y_test)

plt.show()

# %%
model.state_dict()
# Out:
# OrderedDict([('first_layer.weight',
#               tensor([[ 0.1313, -0.7443],
#                       [ 0.9456,  0.0748],
#                       [ 0.0179,  0.3678],
#                       [-0.6373,  0.4303],
#                       [-0.4665,  0.2597]])),
#              ('first_layer.bias',
#               tensor([ 0.8186, -1.1438,  1.5120, -0.8746, -1.6648])),
#              ('second_layer.weight',
#               tensor([[ 0.2465, -0.2428,  2.7325, -0.5471,  0.1779],
#                       [ 0.7582, -0.5790,  1.5354, -0.1727, -0.9902],
#                       [ 0.3732, -0.5035,  1.7308,  0.0450, -1.2335],
#                       [-0.8480,  1.5751, -1.0723,  0.0055, -0.1061],
#                       [ 0.3851, -0.3475, -1.1451,  1.5611,  0.7953]])),
#              ('second_layer.bias',
#               tensor([-0.2039,  1.2834,  1.2319, -1.3196, -1.0155])),
#              ('third_layer.weight',
#               tensor([[ 0.2347,  1.5253,  1.2461, -1.6104, -1.2559]])),
#              ('third_layer.bias', tensor([1.0275]))])
